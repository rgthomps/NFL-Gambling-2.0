# %%
import pandas as pd

# %%
df = pd.read_csv('Data/spreadspoke_scores.csv')
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
# 13231     2/13/2022             2021     Superbowl              True
#
#                   team_home  score_home  score_away            team_away  \
# ...

# %%
df = df.loc[(df['schedule_season'] >= 1979) & (df['schedule_week'].str.lower() != 'superbowl')]
df = df.loc[df['team_favorite_id'] != "PICK"]
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#                   team_home  score_home  score_away            team_away  \
# ...

# %%
home_teams = list(df['team_home'].values)
home_teams
# Out:
# ['Tampa Bay Buccaneers',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'New England Patriots',
#  'Denver Broncos',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Green Bay Packers',
#  'Miami Dolphins',
#  'New England Patriots',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Philadelphia Eagles',
#  'Atlanta Falcons',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Denver Broncos',
# ...

# %%
home_team_ab = []
for team in home_teams:
    if team.__contains__('Cardinals'):
        home_team_ab.append('ARI')
    elif team.__contains__('Falcons'):
        home_team_ab.append('ATL')
    elif team.__contains__('Ravens'):
        home_team_ab.append('BAL')
    elif team.__contains__('Bills'):
        home_team_ab.append('BUF')
    elif team.__contains__('Panthers'):
        home_team_ab.append('CAR')
    elif team.__contains__('Bears'):
        home_team_ab.append('CHI')
    elif team.__contains__('Bengals'):
        home_team_ab.append('CIN')
    elif team.__contains__('Browns'):
        home_team_ab.append('CLE')
    elif team.__contains__('Cowboys'):
        home_team_ab.append('DAL')
    elif team.__contains__('Broncos'):
        home_team_ab.append('DEN')
    elif team.__contains__('Lions'):
        home_team_ab.append('DET')
    elif team.__contains__('Packers'):
        home_team_ab.append('GB')
    elif team.__contains__('Texans'):
        home_team_ab.append('HOU')
    elif team.__contains__('Colts'):
        home_team_ab.append('IND')
    elif team.__contains__('Jaguars'):
        home_team_ab.append('JAX')
    elif team.__contains__('Chiefs'):
        home_team_ab.append('KC')
    elif team.__contains__('Chargers'):
        home_team_ab.append('LAC')
    elif team.__contains__('Rams'):
        home_team_ab.append('LAR')
    elif team.__contains__('Dolphins'):
        home_team_ab.append('MIA')
    elif team.__contains__('Vikings'):
        home_team_ab.append('MIN')
    elif team.__contains__('Patriots'):
        home_team_ab.append('NE')
    elif team.__contains__('Saints'):
        home_team_ab.append('NO')
    elif team.__contains__('Giants'):
        home_team_ab.append('NYG')
    elif team.__contains__('Jets'):
        home_team_ab.append('NYJ')
    elif team.__contains__('Raiders'):
        home_team_ab.append('LVR')
    elif team.__contains__('Eagles'):
        home_team_ab.append('PHI')
    elif team.__contains__('Steelers'):
        home_team_ab.append('PIT')
    elif team.__contains__('Seahawks'):
        home_team_ab.append('SEA')
    elif team.__contains__('49ers'):
        home_team_ab.append('SF')
    elif team.__contains__('Buccaneers'):
        home_team_ab.append('TB')
    elif team.__contains__('Oilers'):
        home_team_ab.append('TEN')
    elif team.__contains__('Titans'):
        home_team_ab.append('TEN')
    elif team.__contains__('Redskins'):
        home_team_ab.append('WAS')
    elif team.__contains__('Football Team'):
        home_team_ab.append('WAS')

# %%
df['team_home'] = home_team_ab
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away            team_away team_favorite_id  \
# ...

# %%
away_teams = list(df['team_away'].values)
away_teams
# Out:
# ['Detroit Lions',
#  'Miami Dolphins',
#  'Green Bay Packers',
#  'Cincinnati Bengals',
#  'Baltimore Colts',
#  'Oakland Raiders',
#  'San Francisco 49ers',
#  'Atlanta Falcons',
#  'Cleveland Browns',
#  'New York Giants',
#  'San Diego Chargers',
#  'Dallas Cowboys',
#  'Houston Oilers',
#  'Pittsburgh Steelers',
#  'Los Angeles Rams',
#  'Cincinnati Bengals',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'New York Jets',
#  'St. Louis Cardinals',
#  'Houston Oilers',
#  'Oakland Raiders',
#  'Dallas Cowboys',
#  'Atlanta Falcons',
#  'Denver Broncos',
#  'New England Patriots',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Tampa Bay Buccaneers',
#  'Kansas City Chiefs',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'Philadelphia Eagles',
#  'Detroit Lions',
#  'Buffalo Bills',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'New York Giants',
#  'New York Jets',
#  'Houston Oilers',
#  'Seattle Seahawks',
#  'Atlanta Falcons',
# ...

# %%
away_team_ab = []
for team in away_teams:
    if team.__contains__('Cardinals'):
        away_team_ab.append('ARI')
    elif team.__contains__('Falcons'):
        away_team_ab.append('ATL')
    elif team.__contains__('Ravens'):
        away_team_ab.append('BAL')
    elif team.__contains__('Bills'):
        away_team_ab.append('BUF')
    elif team.__contains__('Panthers'):
        away_team_ab.append('CAR')
    elif team.__contains__('Bears'):
        away_team_ab.append('CHI')
    elif team.__contains__('Bengals'):
        away_team_ab.append('CIN')
    elif team.__contains__('Browns'):
        away_team_ab.append('CLE')
    elif team.__contains__('Cowboys'):
        away_team_ab.append('DAL')
    elif team.__contains__('Broncos'):
        away_team_ab.append('DEN')
    elif team.__contains__('Lions'):
        away_team_ab.append('DET')
    elif team.__contains__('Packers'):
        away_team_ab.append('GB')
    elif team.__contains__('Texans'):
        away_team_ab.append('HOU')
    elif team.__contains__('Colts'):
        away_team_ab.append('IND')
    elif team.__contains__('Jaguars'):
        away_team_ab.append('JAX')
    elif team.__contains__('Chiefs'):
        away_team_ab.append('KC')
    elif team.__contains__('Chargers'):
        away_team_ab.append('LAC')
    elif team.__contains__('Rams'):
        away_team_ab.append('LAR')
    elif team.__contains__('Dolphins'):
        away_team_ab.append('MIA')
    elif team.__contains__('Vikings'):
        away_team_ab.append('MIN')
    elif team.__contains__('Patriots'):
        away_team_ab.append('NE')
    elif team.__contains__('Saints'):
        away_team_ab.append('NO')
    elif team.__contains__('Giants'):
        away_team_ab.append('NYG')
    elif team.__contains__('Jets'):
        away_team_ab.append('NYJ')
    elif team.__contains__('Raiders'):
        away_team_ab.append('LVR')
    elif team.__contains__('Eagles'):
        away_team_ab.append('PHI')
    elif team.__contains__('Steelers'):
        away_team_ab.append('PIT')
    elif team.__contains__('Seahawks'):
        away_team_ab.append('SEA')
    elif team.__contains__('49ers'):
        away_team_ab.append('SF')
    elif team.__contains__('Buccaneers'):
        away_team_ab.append('TB')
    elif team.__contains__('Oilers'):
        away_team_ab.append('TEN')
    elif team.__contains__('Titans'):
        away_team_ab.append('TEN')
    elif team.__contains__('Redskins'):
        away_team_ab.append('WAS')
    elif team.__contains__('Football Team'):
        away_team_ab.append('WAS')

# %%
df['team_away'] = away_team_ab

n_home_teams = list(df['team_home'].values)

n_away_teams = list(df['team_away'].values)

fav_team = list(df['team_favorite_id'])

score_home = list(df['score_home'].values)

score_away = list(df['score_away'].values)

# %%
len(df)
# Out:
# 10545

# %%
favorite_win = []
for score in list(range(0,len(df))):
    if score_home[score] > score_away[score]:
        if n_home_teams[score] == fav_team[score]:
            favorite_win.append(True)
        else:
            favorite_win.append(False)
    elif score_home[score] < score_away[score]:
        if n_away_teams[score] == fav_team[score]:
            favorite_win.append(True)
        else:
            favorite_win.append(False)
    elif score_home[score] == score_away[score]:
        favorite_win.append(False)

# %%
df['favorite wins'] = favorite_win

# %%
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2501         TB        31.0        16.0       DET               TB
# ...

# %%
df = df.drop(columns='weather_detail')
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2501         TB        31.0        16.0       DET               TB
# ...

# %%
df = df.drop(columns='weather_humidity')
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2501         TB        31.0        16.0       DET               TB
# ...

# %%
df['team_home'].value_counts()
# Out:
# SF     362
# PIT    361
# PHI    359
# NE     359
# DEN    357
# MIA    354
# GB     354
# DAL    354
# KC     350
# LVR    349
# CHI    349
# MIN    349
# NYG    349
# WAS    348
# TEN    347
# BUF    347
# SEA    346
# NO     345
# IND    345
# LAR    344
# LAC    343
# CIN    342
# ATL    341
# TB     341
# NYJ    340
# ARI    339
# DET    334
# CLE    316
# JAX    220
# CAR    219
# BAL    215
# HOU    167
# Name: team_home, dtype: int64

# %%
sf = df.loc[(df['team_home'] == 'SF') & (df['weather_temperature'] != 'NaN')]

# %%
sf['weather_temperature'].median()
# Out:
# 58.0

# %%
sf_nan = df.loc[(df['weather_temperature'].isna()) & (df['team_home'] == 'SF')]
sf_nan['weather_temperature'].replace('NaN', '58.0')
# Out:
# 3196    NaN
# 3198    NaN
# 3568    NaN
# 3801    NaN
# 3805    NaN
# 4444    NaN
# 4679    NaN
# 4910    NaN
# 4914    NaN
# 5145    NaN
# 5149    NaN
# 5615    NaN
# 5619    NaN
# 5850    NaN
# 6085    NaN
# 6089    NaN
# 6336    NaN
# 6585    NaN
# 6838    NaN
# 6842    NaN
# 7087    NaN
# 8131    NaN
# 10536   NaN
# 10540   NaN
# 10803   NaN
# 12455   NaN
# 12488   NaN
# 12529   NaN
# 12558   NaN
# 12569   NaN
# 12583   NaN
# 12631   NaN
# 12636   NaN
# 12672   NaN
# 12676   NaN
# 12690   NaN
# 12736   NaN
# 12750   NaN
# 12764   NaN
# 12797   NaN
# 12882   NaN
# 12932   NaN
# 12992   NaN
# 13009   NaN
# 13050   NaN
# 13081   NaN
# 13096   NaN
# 13125   NaN
# Name: weather_temperature, dtype: float64

# %%
pit = df.loc[(df['team_home'] == 'PIT') & (df['weather_temperature'] != 'NaN')]

# %%
pit['weather_temperature'].median()
# Out:
# 47.0

# %%
ne = df.loc[(df['team_home'] == 'NE') & (df['weather_temperature'] != 'NaN')]

# %%
ne['weather_temperature'].median()
# Out:
# 50.0

# %%
phi = df.loc[(df['team_home'] == 'PHI') & (df['weather_temperature'] != 'NaN')]

# %%
phi['weather_temperature'].median()
# Out:
# 53.0

# %%
den = df.loc[(df['team_home'] == 'DEN') & (df['weather_temperature'] != 'NaN')]

# %%
den['weather_temperature'].median()
# Out:
# 48.0

# %%
mia = df.loc[(df['team_home'] == 'MIA') & (df['weather_temperature'] != 'NaN')]

# %%
mia['weather_temperature'].median()
# Out:
# 78.0

# %%
dal = df.loc[(df['team_home'] == 'DAL') & (df['weather_temperature'] != 'NaN')]

# %%
dal['weather_temperature'].median()
# Out:
# 68.0

# %%
gb = df.loc[(df['team_home'] == 'GB') & (df['weather_temperature'] != 'NaN')]

# %%
gb['weather_temperature'].median()
# Out:
# 44.0

# %%
kc = df.loc[(df['team_home'] == 'KC') & (df['weather_temperature'] != 'NaN')]

# %%
kc['weather_temperature'].median()
# Out:
# 53.0

# %%
MIN = df.loc[(df['team_home'] == 'MIN') & (df['weather_temperature'] != 'NaN')]

# %%
MIN['weather_temperature'].median()
# Out:
# 72.0

# %%
lvr = df.loc[(df['team_home'] == 'LVR') & (df['weather_temperature'] != 'NaN')]

# %%
lvr['weather_temperature'].median()
# Out:
# 60.0

# %%
chi = df.loc[(df['team_home'] == 'CHI') & (df['weather_temperature'] != 'NaN')]

# %%
chi['weather_temperature'].median()
# Out:
# 49.0

# %%
nyg = df.loc[(df['team_home'] == 'NYG') & (df['weather_temperature'] != 'NaN')]

# %%
nyg['weather_temperature'].median()
# Out:
# 54.0

# %%
was = df.loc[(df['team_home'] == 'WAS') & (df['weather_temperature'] != 'NaN')]

# %%
was['weather_temperature'].median()
# Out:
# 55.0

# %%
ten = df.loc[(df['team_home'] == 'WAS') & (df['weather_temperature'] != 'NaN')]

# %%
ten['weather_temperature'].median()
# Out:
# 55.0

# %%
buf = df.loc[(df['team_home'] == 'BUF') & (df['weather_temperature'] != 'NaN')]

# %%
buf['weather_temperature'].median()
# Out:
# 48.0

# %%
sea = df.loc[(df['team_home'] == 'SEA') & (df['weather_temperature'] != 'NaN')]

# %%
sea['weather_temperature'].median()
# Out:
# 71.0

# %%
ind = df.loc[(df['team_home'] == 'IND') & (df['weather_temperature'] != 'NaN')]

# %%
ind['weather_temperature'].median()
# Out:
# 72.0

# %%
no = df.loc[(df['team_home'] == 'NO') & (df['weather_temperature'] != 'NaN')]

# %%
no['weather_temperature'].median()
# Out:
# 72.0

# %%
lar = df.loc[(df['team_home'] == 'LAR') & (df['weather_temperature'] != 'NaN')]

# %%
lar['weather_temperature'].median()
# Out:
# 72.0

# %%
lac = df.loc[(df['team_home'] == 'LAC') & (df['weather_temperature'] != 'NaN')]

# %%
lac['weather_temperature'].median()
# Out:
# 65.0

# %%
cin = df.loc[(df['team_home'] == 'CIN') & (df['weather_temperature'] != 'NaN')]

# %%
cin['weather_temperature'].median()
# Out:
# 52.0

# %%
atl = df.loc[(df['team_home'] == 'ATL') & (df['weather_temperature'] != 'NaN')]

# %%
atl['weather_temperature'].median()
# Out:
# 72.0

# %%
tb = df.loc[(df['team_home'] == 'TB') & (df['weather_temperature'] != 'NaN')]

# %%
tb['weather_temperature'].median()
# Out:
# 75.0

# %%
nyj = df.loc[(df['team_home'] == 'NYJ') & (df['weather_temperature'] != 'NaN')]

# %%
nyj['weather_temperature'].median()
# Out:
# 54.0

# %%
ari = df.loc[(df['team_home'] == 'ARI') & (df['weather_temperature'] != 'NaN')]

# %%
ari['weather_temperature'].median()
# Out:
# 72.0

# %%
det = df.loc[(df['team_home'] == 'DET') & (df['weather_temperature'] != 'NaN')]

# %%
det['weather_temperature'].median()
# Out:
# 72.0

# %%
cle = df.loc[(df['team_home'] == 'CLE') & (df['weather_temperature'] != 'NaN')]

# %%
cle['weather_temperature'].median()
# Out:
# 48.0

# %%
jax = df.loc[(df['team_home'] == 'JAX') & (df['weather_temperature'] != 'NaN')]

# %%
jax['weather_temperature'].median()
# Out:
# 72.0

# %%
car = df.loc[(df['team_home'] == 'CAR') & (df['weather_temperature'] != 'NaN')]

# %%
car['weather_temperature'].median()
# Out:
# 57.5

# %%
bal = df.loc[(df['team_home'] == 'BAL') & (df['weather_temperature'] != 'NaN')]

# %%
bal['weather_temperature'].median()
# Out:
# 54.0

# %%
hou = df.loc[(df['team_home'] == 'HOU') & (df['weather_temperature'] != 'NaN')]

# %%
hou['weather_temperature'].median()
# Out:
# 72.0

# %%
df.loc[df['weather_temperature'] == 72]
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2508       9/2/1979             1979             1             False
# 2511       9/2/1979             1979             1             False
# 2534      9/16/1979             1979             3             False
# 2537      9/16/1979             1979             3             False
# 2540      9/16/1979             1979             3             False
# ...             ...              ...           ...               ...
# 13214      1/9/2022             2021            18             False
# 13216      1/9/2022             2021            18             False
# 13221     1/16/2022             2021      Wildcard              True
# 13224     1/17/2022             2021      Wildcard              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2508         NO        34.0        40.0       ATL               NO
# ...

# %%
avg_temp_by_team = df.groupby('team_home')['weather_temperature'].mean().to_dict()
avg_temp_by_team
# Out:
# {'ARI': 66.59882005899705,
#  'ATL': 68.10324483775811,
#  'BAL': 53.9144385026738,
#  'BUF': 48.77707006369427,
#  'CAR': 58.453125,
#  'CHI': 48.06070287539936,
#  'CIN': 51.20967741935484,
#  'CLE': 49.2027972027972,
#  'DAL': 63.857988165680474,
#  'DEN': 48.782334384858046,
#  'DET': 72.0,
#  'GB': 44.09872611464968,
#  'HOU': 72.0969696969697,
#  'IND': 69.95942028985507,
#  'JAX': 69.31443298969072,
#  'KC': 51.05993690851735,
#  'LAC': 65.4104938271605,
#  'LAR': 68.46407185628742,
#  'LVR': 60.75079872204473,
#  'MIA': 76.78980891719745,
#  'MIN': 68.92836676217765,
#  'NE': 49.58990536277602,
#  'NO': 71.83720930232558,
#  'NYG': 53.29206349206349,
#  'NYJ': 54.3525641025641,
#  'PHI': 52.91849529780564,
#  'PIT': 48.139240506329116,
#  'SEA': 61.0984126984127,
#  'SF': 58.43312101910828,
#  'TB': 72.35897435897436,
#  'TEN': 64.1974921630094,
#  'WAS': 55.157051282051285}

# %%
avg_wind_by_game = df.groupby('team_home')['weather_wind_mph'].mean().to_dict()
avg_wind_by_game
# Out:
# {'ARI': 4.961651917404129,
#  'ATL': 2.9970501474926254,
#  'BAL': 6.438502673796791,
#  'BUF': 10.796178343949045,
#  'CAR': 6.28125,
#  'CHI': 10.45367412140575,
#  'CIN': 8.812903225806451,
#  'CLE': 11.153846153846153,
#  'DAL': 8.606508875739644,
#  'DEN': 9.22397476340694,
#  'DET': 0.0,
#  'GB': 10.0,
#  'HOU': 2.0727272727272728,
#  'IND': 0.9420289855072463,
#  'JAX': 8.77319587628866,
#  'KC': 10.785488958990536,
#  'LAC': 6.75,
#  'LAR': 3.461077844311377,
#  'LVR': 8.773162939297125,
#  'MIA': 9.952229299363058,
#  'MIN': 1.2922636103151863,
#  'NE': 11.864353312302839,
#  'NO': 0.1308139534883721,
#  'NYG': 11.99047619047619,
#  'NYJ': 11.657051282051283,
#  'PHI': 9.852664576802507,
#  'PIT': 8.832278481012658,
#  'SEA': 3.8825396825396825,
#  'SF': 9.786624203821656,
#  'TB': 8.070512820512821,
#  'TEN': 3.8181818181818183,
#  'WAS': 8.935897435897436}

# %%
from sklearn.model_selection import train_test_split

# %%
df[['month', 'day', 'year']] = df['schedule_date'].str.split('/', expand=True)

# %%
df = df.drop(columns='day')

# %%
df = df.drop(columns='year')

# %%
df = df.drop(columns='schedule_date')

# %%
df = df.drop(columns='schedule_week')

# %%
df = df.drop(columns= 'schedule_playoff')

# %%
df = df.drop(columns= 'stadium')

# %%
df = df.drop(columns= 'stadium_neutral')

# %%
df = df[df.over_under_line != ' ']

# %%
df['month'] = df['month'].astype(int)

# %%
 df['over_under_line'] = df['over_under_line'].astype(float)

# %%
df
# Out:
#        schedule_season team_home  score_home  score_away team_away  \
# 2501              1979        TB        31.0        16.0       DET
# 2502              1979       BUF         7.0         9.0       MIA
# 2503              1979       CHI         6.0         3.0        GB
# 2504              1979       DEN        10.0         0.0       CIN
# 2505              1979        KC        14.0         0.0       IND
# ...                ...       ...         ...         ...       ...
# 13226             2021       TEN        16.0        19.0       CIN
# 13227             2021        KC        42.0        36.0       BUF
# 13228             2021        TB        27.0        30.0       LAR
# 13229             2021        KC        24.0        27.0       CIN
# 13230             2021       LAR        20.0        17.0        SF
#
#       team_favorite_id  spread_favorite  over_under_line  weather_temperature  \
# 2501                TB             -3.0             30.0                 79.0
# ...

# %%
df
# Out:
#        schedule_season team_home  score_home  score_away team_away  \
# 2501              1979        TB        31.0        16.0       DET
# 2502              1979       BUF         7.0         9.0       MIA
# 2503              1979       CHI         6.0         3.0        GB
# 2504              1979       DEN        10.0         0.0       CIN
# 2505              1979        KC        14.0         0.0       IND
# ...                ...       ...         ...         ...       ...
# 13226             2021       TEN        16.0        19.0       CIN
# 13227             2021        KC        42.0        36.0       BUF
# 13228             2021        TB        27.0        30.0       LAR
# 13229             2021        KC        24.0        27.0       CIN
# 13230             2021       LAR        20.0        17.0        SF
#
#       team_favorite_id  spread_favorite  over_under_line  weather_temperature  \
# 2501                TB             -3.0             30.0                 79.0
# ...

# %%
X = df.drop(columns='favorite wins')
y = df['favorite wins']

# %%
X, X_hold, y, y_hold = train_test_split(X, y, random_state=42, shuffle=False, test_size=60)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.base import BaseEstimator
class GroupImputer(BaseEstimator):
    def __init__(self, fill_col, group_col, strategy):
        self.fill_col = fill_col
        self.group_col = group_col
        self.strategy = strategy
    def fit(self, X, y=None):
        self.val_by_group = X.groupby(self.group_col)[self.fill_col].agg([self.strategy]).to_dict()[self.strategy]
    def transform(self, X):
        X.loc[:, self.fill_col] = X[self.fill_col].fillna(X[self.group_col].map(self.val_by_group))
        return X

# %%
group_imputer = GroupImputer(fill_col= 'weather_temperature', group_col='team_home', strategy='mean')

group_imputer.fit(X_train)

# %%
X_train = group_imputer.transform(X_train)
X_test = group_imputer.transform(X_test)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
class windImputer(BaseEstimator):
    def __init__(self, fill_col, wind_col, strategy):
        self.fill_col = fill_col
        self.wind_col = wind_col
        self.strategy = strategy
    def fit(self, X, y=None):
        self.val_by_wind = X.groupby(self.wind_col)[self.fill_col].agg([self.strategy]).to_dict()[self.strategy]
    def transform(self, X):
        X.loc[:, self.fill_col] = X[self.fill_col].fillna(X[self.wind_col].map(self.val_by_wind))
        return X

# %%
wind_imputer = GroupImputer(fill_col= 'weather_wind_mph', group_col='team_home', strategy='mean')

wind_imputer.fit(X_train)

# %%
X_train = wind_imputer.transform(X_train)
X_test = wind_imputer.transform(X_test)

# %%
cat_columns = [c for c in X_train.columns if X_train[c].dtype == 'O']

# %%
cat_columns
# Out:
# ['team_home', 'team_away', 'team_favorite_id']

# %%
[c for c in X_train.columns if X_train[c].dtype in ['int64', 'float64']]
# Out:
# ['schedule_season',
#  'score_home',
#  'score_away',
#  'spread_favorite',
#  'over_under_line',
#  'weather_temperature',
#  'weather_wind_mph',
#  'month']

# %%
num_columns = [
    'schedule_season',
    'score_home',
    'score_away',
    'spread_favorite',
    'weather_temperature',
    'weather_wind_mph',
    'over_under_line'
]

# %%
used_cols = [*cat_columns, *num_columns]
used_cols
# Out:
# ['team_home',
#  'team_away',
#  'team_favorite_id',
#  'schedule_season',
#  'score_home',
#  'score_away',
#  'spread_favorite',
#  'weather_temperature',
#  'weather_wind_mph',
#  'over_under_line']

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
cat_transformer = OneHotEncoder(drop='first', handle_unknown = 'error', sparse= False)

num_transformer = StandardScaler()

# %%
preprocessor = ColumnTransformer([
    ('cats', cat_transformer, cat_columns),
    ('nums', num_transformer, num_columns)
])

# %%
pd.Series(y_train).value_counts(normalize=True)
# Out:
# True     0.664833
# False    0.335167
# Name: favorite wins, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import plot_confusion_matrix, plot_roc_curve, f1_score, precision_score, roc_auc_score

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf_dt = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('tree', DecisionTreeClassifier(random_state=42, max_depth=10))
])

clf_dt.fit(X_train[used_cols], y_train)

train_preds = clf_dt.predict(X_train[used_cols])
test_preds = clf_dt.predict(X_test[used_cols])

train_probas = clf_dt.predict_proba(X_train[used_cols])[:, 1]
test_probas = clf_dt.predict_proba(X_test[used_cols])[:, 1]

# %%
param_grid = {
    "tree__max_depth": [5, 6, 7],
    "tree__min_samples_leaf": [5, 6, 7]
}

# %%
gs = GridSearchCV(clf_dt, param_grid, cv=5, scoring="roc_auc")
gs.fit(X_train[used_cols], y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('cats',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse=False),
#                                                                          ['team_home',
#                                                                           'team_away',
#                                                                           'team_favorite_id']),
#                                                                         ('nums',
#                                                                          StandardScaler(),
#                                                                          ['schedule_season',
# ...

# %%
gs.best_params_
# Out:
# {'tree__max_depth': 7, 'tree__min_samples_leaf': 5}

# %%
gs.best_score_
# Out:
# 0.6980470936896166

# %%
def evaluate(model, Xtr, Xte, ytr, yte):
    train_preds = model.predict(X_train[used_cols])
    test_preds = model.predict(X_test[used_cols])

    train_probas = clf_dt.predict_proba(X_train[used_cols])[:, 1]
    test_probas = clf_dt.predict_proba(X_test[used_cols])[:, 1]

    plot_confusion_matrix(model, Xte, yte)
    plot_roc_curve(model, X_test[used_cols], y_test);
    
    print(f"Train F1: {f1_score(ytr, train_preds):.4f}")
    print(f"Train Precision: {precision_score(ytr, train_preds):.4f}")
    print(f"Train ROC-AUC: {roc_auc_score(ytr, train_preds):.4f}")
    print("*" * 20)
    print(f"Test F1: {f1_score(yte, test_preds):.4f}")
    print(f"Test Precision: {precision_score(yte, test_preds):.4f}")
    print(f"Test ROC-AUC: {roc_auc_score(yte, test_preds):.4f}")

# %%
evaluate(clf_dt, X_train[used_cols], X_test[used_cols], y_train, y_test)
# Out:
# Train F1: 0.8263
# Train Precision: 0.8245
# Train ROC-AUC: 0.7393
# ********************
# Test F1: 0.7586
# Test Precision: 0.7461
# Test ROC-AUC: 0.6476

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf_lr = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('logreg', LogisticRegression(max_iter=200))
])

clf_lr.fit(X_train[used_cols], y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cats',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['team_home', 'team_away',
#                                                    'team_favorite_id']),
#                                                  ('nums', StandardScaler(),
#                                                   ['schedule_season',
#                                                    'score_home', 'score_away',
#                                                    'spread_favorite',
#                                                    'weather_temperature',
#                                                    'weather_wind_mph',
#                                                    'over_under_line'])])),
# ...

# %%
evaluate(clf_lr, X_train[used_cols], X_test[used_cols], y_train, y_test)
# Out:
# Train F1: 0.7859
# Train Precision: 0.7023
# Train ROC-AUC: 0.5709
# ********************
# Test F1: 0.7583
# Test Precision: 0.6697
# Test ROC-AUC: 0.5460

# %%
from sklearn.naive_bayes import ComplementNB, GaussianNB
import numpy as np

# %%
clf_nb = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('bayes', GaussianNB())
])
clf_nb.fit(X_train[used_cols], y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cats',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['team_home', 'team_away',
#                                                    'team_favorite_id']),
#                                                  ('nums', StandardScaler(),
#                                                   ['schedule_season',
#                                                    'score_home', 'score_away',
#                                                    'spread_favorite',
#                                                    'weather_temperature',
#                                                    'weather_wind_mph',
#                                                    'over_under_line'])])),
#                 ('bayes', GaussianNB())])

# %%
evaluate(clf_nb, X_train[used_cols], X_test[used_cols], y_train, y_test)
# Out:
# Train F1: 0.6398
# Train Precision: 0.7183
# Train ROC-AUC: 0.5640
# ********************
# Test F1: 0.6081
# Test Precision: 0.6703
# Test ROC-AUC: 0.5299

# %%
60* 50
# Out:
# 3000

# %%
sum(y_hold * 50)
# Out:
# 2000

# %%
sum(clf_dt.predict(X_hold[used_cols]) * 50)
# Out:
# 2150

# %%
hold_probas = clf_dt.predict_proba(X_hold[used_cols])[:,1]

# %%
sum(np.where(hold_probas >=.75, 1, 0) * 50)
# Out:
# 1600
