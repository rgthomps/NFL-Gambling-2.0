# %%
# !ls ../../Data
# Out:
# nfl_stadiums.csv       spreadspoke.R
# nfl_teams.csv          spreadspoke_scores.csv

# %%
import pandas as pd

# %%
stadiums_data = pd.read_csv("../../Data/nfl_stadiums.csv", encoding='unicode_escape')
stadiums_data
# Out:
#              stadium_name   stadium_location  stadium_open  stadium_close  \
# 0              Alamo Dome    San Antonio, TX           NaN            NaN
# 1       Allegiant Stadium       Paradise, NV        2020.0            NaN
# 2          Alltel Stadium   Jacksonville, FL           NaN            NaN
# 3          Alumni Stadium  Chestnut Hill, MA           NaN            NaN
# 4         Anaheim Stadium        Anaheim, CA        1980.0         1994.0
# ..                    ...                ...           ...            ...
# 101  War Memorial Stadium        Buffalo, NY        1960.0         1972.0
# 102       Wembley Stadium         London, UK        2007.0            NaN
# 103         Wrigley Field        Chicago, IL        1920.0         1970.0
# 104             Yale Bowl      New Haven, CT           NaN            NaN
# 105        Yankee Stadium          Bronx, NY           NaN            NaN
#
#     stadium_type                              stadium_address  \
# 0         indoor        100 Montana St, San Antonio, TX 78203
# 1         indoor                                          NaN
# 2            NaN                                          NaN
# 3        outdoor        Perimeter Rd, Chestnut Hill, MA 02467
# 4        outdoor     2000 E Gene Autry Way, Anaheim, CA 92806
# ..           ...                                          ...
# 101      outdoor          285 Dodge Street, Buffalo, NY 14208
# 102      outdoor      Wembley, London HA9 0WS, United Kingdom
# 103      outdoor  1060 West Addison Street, Chicago, IL 60613
# 104      outdoor          276 Derby Ave, West Haven, CT 06516
# 105      outdoor                                          NaN
#
#     stadium_weather_station_code stadium_weather_type stadium_capacity  \
# 0                          78203                 dome            72000
# 1                            NaN                 dome            65000
# 2                            NaN                  NaN              NaN
# 3                           2467                 cold              NaN
# 4                          92806                 warm              NaN
# ..                           ...                  ...              ...
# 101                        14208                 cold              NaN
# 102                 Heathrow, UK             moderate              NaN
# 103                        60613                 cold              NaN
# 104                         6516                 cold              NaN
# 105                          NaN                 cold              NaN
#
#     stadium_surface STATION NAME  LATITUDE  LONGITUDE  ELEVATION
# 0         FieldTurf     NaN  NaN       NaN        NaN        NaN
# 1             Grass     NaN  NaN       NaN        NaN        NaN
# 2               NaN     NaN  NaN       NaN        NaN        NaN
# 3             Grass     NaN  NaN       NaN        NaN        NaN
# 4               NaN     NaN  NaN       NaN        NaN        NaN
# ..              ...     ...  ...       ...        ...        ...
# 101             NaN     NaN  NaN       NaN        NaN        NaN
# 102             NaN     NaN  NaN       NaN        NaN        NaN
# 103             NaN     NaN  NaN       NaN        NaN        NaN
# 104           Grass     NaN  NaN       NaN        NaN        NaN
# 105             NaN     NaN  NaN       NaN        NaN        NaN
#
# [106 rows x 15 columns]

# %%
df = pd.read_csv("../../Data/spreadspoke_scores.csv")
len(df)
# Out:
# 13232

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13232 entries, 0 to 13231
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        13232 non-null  object
#  1   schedule_season      13232 non-null  int64
#  2   schedule_week        13232 non-null  object
#  3   schedule_playoff     13232 non-null  bool
#  4   team_home            13232 non-null  object
#  5   score_home           13231 non-null  float64
#  6   score_away           13231 non-null  float64
#  7   team_away            13232 non-null  object
#  8   team_favorite_id     10753 non-null  object
#  9   spread_favorite      10753 non-null  float64
#  10  over_under_line      10743 non-null  object
#  11  stadium              13232 non-null  object
#  12  stadium_neutral      13232 non-null  bool
#  13  weather_temperature  12189 non-null  float64
#  14  weather_wind_mph     12172 non-null  float64
#  15  weather_humidity     8441 non-null   float64
#  16  weather_detail       2822 non-null   object
# dtypes: bool(2), float64(6), int64(1), object(8)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#        schedule_season    score_home    score_away  spread_favorite  \
# count     13232.000000  13231.000000  13231.000000     10753.000000
# mean       1995.526678     22.450004     19.758370        -5.395332
# std          15.858890     10.553505     10.180527         3.440927
# min        1966.000000      0.000000      0.000000       -26.500000
# 25%        1982.000000     14.000000     13.000000        -7.000000
# 50%        1997.000000     22.000000     20.000000        -4.500000
# 75%        2009.000000     29.000000     27.000000        -3.000000
# max        2021.000000     72.000000     62.000000         0.000000
#
#        weather_temperature  weather_wind_mph  weather_humidity
# count         12189.000000      12172.000000       8441.000000
# mean             58.770039          7.747125         67.218813
# std              15.539390          5.677280         15.784069
# min              -6.000000          0.000000          4.000000
# 25%              48.000000          3.000000         57.000000
# 50%              61.000000          8.000000         69.000000
# 75%              72.000000         12.000000         79.000000
# max              97.000000         40.000000        100.000000

# %%
df = df[df.over_under_line != ' ']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13170 entries, 0 to 13231
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        13170 non-null  object
#  1   schedule_season      13170 non-null  int64
#  2   schedule_week        13170 non-null  object
#  3   schedule_playoff     13170 non-null  bool
#  4   team_home            13170 non-null  object
#  5   score_home           13169 non-null  float64
#  6   score_away           13169 non-null  float64
#  7   team_away            13170 non-null  object
#  8   team_favorite_id     10691 non-null  object
#  9   spread_favorite      10691 non-null  float64
#  10  over_under_line      10681 non-null  object
#  11  stadium              13170 non-null  object
#  12  stadium_neutral      13170 non-null  bool
#  13  weather_temperature  12185 non-null  float64
#  14  weather_wind_mph     12168 non-null  float64
#  15  weather_humidity     8441 non-null   float64
#  16  weather_detail       2818 non-null   object
# dtypes: bool(2), float64(6), int64(1), object(8)
# memory usage: 1.6+ MB

# %%
df = df.loc[(df['schedule_season'] >= 1979) & (df['schedule_week'] != 'Superbowl')]
df = df.loc[df['team_favorite_id'] != "PICK"]
df
# superbowl, 1979, take out PICK from team favorite,
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#                   team_home  score_home  score_away            team_away  \
# 2501   Tampa Bay Buccaneers        31.0        16.0        Detroit Lions
# 2502          Buffalo Bills         7.0         9.0       Miami Dolphins
# 2503          Chicago Bears         6.0         3.0    Green Bay Packers
# 2504         Denver Broncos        10.0         0.0   Cincinnati Bengals
# 2505     Kansas City Chiefs        14.0         0.0      Baltimore Colts
# ...                     ...         ...         ...                  ...
# 13226      Tennessee Titans        16.0        19.0   Cincinnati Bengals
# 13227    Kansas City Chiefs        42.0        36.0        Buffalo Bills
# 13228  Tampa Bay Buccaneers        27.0        30.0     Los Angeles Rams
# 13229    Kansas City Chiefs        24.0        27.0   Cincinnati Bengals
# 13230      Los Angeles Rams        20.0        17.0  San Francisco 49ers
#
#       team_favorite_id  spread_favorite over_under_line  \
# 2501                TB             -3.0              30
# 2502               MIA             -5.0              39
# 2503               CHI             -3.0              31
# 2504               DEN             -3.0            31.5
# 2505                KC             -1.0              37
# ...                ...              ...             ...
# 13226              TEN             -4.0            48.5
# 13227               KC             -2.5            54.0
# 13228               TB             -3.0            48.0
# 13229               KC             -7.0            54.5
# 13230              LAR             -3.5            46.0
#
#                      stadium  stadium_neutral  weather_temperature  \
# 2501      Houlihan's Stadium            False                 79.0
# 2502    Ralph Wilson Stadium            False                 74.0
# 2503           Soldier Field            False                 78.0
# 2504       Mile High Stadium            False                 69.0
# 2505       Arrowhead Stadium            False                 76.0
# ...                      ...              ...                  ...
# 13226         Nissan Stadium            False                 35.0
# 13227      Arrowhead Stadium            False                 35.0
# 13228  Raymond James Stadium            False                 50.0
# 13229      Arrowhead Stadium            False                 41.0
# 13230           SoFi Stadium            False                 72.0
#
#        weather_wind_mph  weather_humidity weather_detail
# 2501                9.0              87.0            NaN
# 2502               15.0              74.0            NaN
# 2503               11.0              68.0            NaN
# 2504                6.0              38.0            NaN
# 2505                8.0              71.0            NaN
# ...                 ...               ...            ...
# 13226               0.0              43.0            NaN
# 13227               6.0              54.0            NaN
# 13228              11.0              69.0            NaN
# 13229               4.0              41.0            NaN
# 13230               0.0               NaN           DOME
#
# [10484 rows x 17 columns]

# %%
home_teams = list(df['team_home'].values)
home_teams
# Out:
# ['Tampa Bay Buccaneers',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'New England Patriots',
#  'Denver Broncos',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Green Bay Packers',
#  'Miami Dolphins',
#  'New England Patriots',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Philadelphia Eagles',
#  'Atlanta Falcons',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Cleveland Browns',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'New Orleans Saints',
#  'New York Jets',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'Green Bay Packers',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Denver Broncos',
#  'Houston Oilers',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Oakland Raiders',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'New York Giants',
#  'Oakland Raiders',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'New York Jets',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Jets',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Pittsburgh Steelers',
#  'Oakland Raiders',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Atlanta Falcons',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'New York Giants',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Miami Dolphins',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Washington Redskins',
#  'Dallas Cowboys',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Houston Oilers',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Los Angeles Rams',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'New England Patriots',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Tampa Bay Buccaneers',
#  'Seattle Seahawks',
#  'Miami Dolphins',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'New Orleans Saints',
#  'Philadelphia Eagles',
#  'Seattle Seahawks',
#  'Atlanta Falcons',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'Oakland Raiders',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Houston Oilers',
#  'Detroit Lions',
#  'Miami Dolphins',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'New England Patriots',
#  'New York Giants',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'Tampa Bay Buccaneers',
#  'San Diego Chargers',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Tampa Bay Buccaneers',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Giants',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Cleveland Browns',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'New Orleans Saints',
#  'New York Jets',
#  'Oakland Raiders',
#  'Seattle Seahawks',
#  'Philadelphia Eagles',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'New England Patriots',
#  'Atlanta Falcons',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'Chicago Bears',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Kansas City Chiefs',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Giants',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Denver Broncos',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Denver Broncos',
#  'Houston Oilers',
#  'Miami Dolphins',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Washington Redskins',
#  'Pittsburgh Steelers',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'New York Giants',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Washington Redskins',
#  'New York Jets',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'New England Patriots',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Cleveland Browns',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Green Bay Packers',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Oakland Raiders',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Houston Oilers',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'Washington Redskins',
#  'Seattle Seahawks',
#  'Miami Dolphins',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'New Orleans Saints',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'New Orleans Saints',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Oakland Raiders',
#  'Houston Oilers',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Kansas City Chiefs',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Miami Dolphins',
#  'San Diego Chargers',
#  'Washington Redskins',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Tampa Bay Buccaneers',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'New Orleans Saints',
#  'New York Giants',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'San Diego Chargers',
#  'Tampa Bay Buccaneers',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Los Angeles Rams',
#  'New England Patriots',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'Washington Redskins',
#  'Cleveland Browns',
#  'Miami Dolphins',
#  'Baltimore Colts',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'Washington Redskins',
#  'Minnesota Vikings',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New York Giants',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Chicago Bears',
#  'Buffalo Bills',
#  'Houston Oilers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'Oakland Raiders',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Philadelphia Eagles',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Green Bay Packers',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Jets',
#  'Oakland Raiders',
#  'Seattle Seahawks',
#  'Detroit Lions',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'New Orleans Saints',
#  'New York Jets',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Pittsburgh Steelers',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Green Bay Packers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'New Orleans Saints',
#  'New York Giants',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Denver Broncos',
#  'Baltimore Colts',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Dallas Cowboys',
#  'Atlanta Falcons',
#  'Cincinnati Bengals',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Seattle Seahawks',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'New York Jets',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'Tampa Bay Buccaneers',
#  'Atlanta Falcons',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Houston Oilers',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Jets',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'Houston Oilers',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Miami Dolphins',
#  'New York Giants',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Oakland Raiders',
#  'Cleveland Browns',
#  'Detroit Lions',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Kansas City Chiefs',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Oakland Raiders',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'New York Giants',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Detroit Lions',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Seattle Seahawks',
#  'San Diego Chargers',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Dallas Cowboys',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Denver Broncos',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'New England Patriots',
#  'Pittsburgh Steelers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'New York Giants',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'St. Louis Cardinals',
#  'Los Angeles Raiders',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Jets',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Washington Redskins',
#  'Tampa Bay Buccaneers',
#  'Los Angeles Rams',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Los Angeles Raiders',
#  'Miami Dolphins',
#  'New Orleans Saints',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'Washington Redskins',
#  'Detroit Lions',
#  'New York Giants',
#  'San Francisco 49ers',
#  'Atlanta Falcons',
#  'Cincinnati Bengals',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Jets',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Houston Oilers',
#  'Los Angeles Raiders',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'San Diego Chargers',
#  'Atlanta Falcons',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Raiders',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Miami Dolphins',
#  'Baltimore Colts',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Minnesota Vikings',
#  'San Francisco 49ers',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Minnesota Vikings',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Los Angeles Raiders',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'New York Jets',
#  'St. Louis Cardinals',
#  'Kansas City Chiefs',
#  'Cleveland Browns',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Los Angeles Raiders',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'New York Giants',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Houston Oilers',
#  'Los Angeles Raiders',
#  'Miami Dolphins',
#  'New York Giants',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Cincinnati Bengals',
#  'Baltimore Colts',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Jets',
#  'Pittsburgh Steelers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Green Bay Packers',
#  'Baltimore Colts',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'St. Louis Cardinals',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Denver Broncos',
#  'Los Angeles Raiders',
#  'Miami Dolphins',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'San Diego Chargers',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Washington Redskins',
#  'Detroit Lions',
#  'Baltimore Colts',
#  'Cleveland Browns',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Los Angeles Raiders',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New York Giants',
#  'New York Jets',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Atlanta Falcons',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'New England Patriots',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'St. Louis Cardinals',
#  'New Orleans Saints',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Los Angeles Raiders',
#  'Los Angeles Rams',
#  'New Orleans Saints',
#  'New York Jets',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Miami Dolphins',
#  'San Diego Chargers',
#  'Baltimore Colts',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Washington Redskins',
#  'Detroit Lions',
#  'Miami Dolphins',
#  'New York Jets',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Houston Oilers',
#  'Los Angeles Raiders',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'Tampa Bay Buccaneers',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'Washington Redskins',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Detroit Lions',
#  'Kansas City Chiefs',
#  'Los Angeles Raiders',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'St. Louis Cardinals',
#  'Buffalo Bills',
#  'Chicago Bears',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Indianapolis Colts',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Giants',
#  ...]

# %%
home_team_ab = []
for team in home_teams:
    if team.__contains__('Cardinals'):
        home_team_ab.append('ARI')
    elif team.__contains__('Falcons'):
        home_team_ab.append('ATL')
    elif team.__contains__('Ravens'):
        home_team_ab.append('BAL')
    elif team.__contains__('Bills'):
        home_team_ab.append('BUF')
    elif team.__contains__('Panthers'):
        home_team_ab.append('CAR')
    elif team.__contains__('Bears'):
        home_team_ab.append('CHI')
    elif team.__contains__('Bengals'):
        home_team_ab.append('CIN')
    elif team.__contains__('Browns'):
        home_team_ab.append('CLE')
    elif team.__contains__('Cowboys'):
        home_team_ab.append('DAL')
    elif team.__contains__('Broncos'):
        home_team_ab.append('DEN')
    elif team.__contains__('Lions'):
        home_team_ab.append('DET')
    elif team.__contains__('Packers'):
        home_team_ab.append('GB')
    elif team.__contains__('Texans'):
        home_team_ab.append('HOU')
    elif team.__contains__('Colts'):
        home_team_ab.append('IND')
    elif team.__contains__('Jaguars'):
        home_team_ab.append('JAX')
    elif team.__contains__('Chiefs'):
        home_team_ab.append('KC')
    elif team.__contains__('Chargers'):
        home_team_ab.append('LAC')
    elif team.__contains__('Rams'):
        home_team_ab.append('LAR')
    elif team.__contains__('Dolphins'):
        home_team_ab.append('MIA')
    elif team.__contains__('Vikings'):
        home_team_ab.append('MIN')
    elif team.__contains__('Patriots'):
        home_team_ab.append('NE')
    elif team.__contains__('Saints'):
        home_team_ab.append('NO')
    elif team.__contains__('Giants'):
        home_team_ab.append('NYG')
    elif team.__contains__('Jets'):
        home_team_ab.append('NYJ')
    elif team.__contains__('Raiders'):
        home_team_ab.append('LVR')
    elif team.__contains__('Eagles'):
        home_team_ab.append('PHI')
    elif team.__contains__('Steelers'):
        home_team_ab.append('PIT')
    elif team.__contains__('Seahawks'):
        home_team_ab.append('SEA')
    elif team.__contains__('49ers'):
        home_team_ab.append('SF')
    elif team.__contains__('Buccaneers'):
        home_team_ab.append('TB')
    elif team.__contains__('Oilers'):
        home_team_ab.append('TEN')
    elif team.__contains__('Titans'):
        home_team_ab.append('TEN')
    elif team.__contains__('Redskins'):
        home_team_ab.append('WAS')
    elif team.__contains__('Football Team'):
        home_team_ab.append('WAS')

# %%
df['team_home'] = home_team_ab
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away            team_away team_favorite_id  \
# 2501         TB        31.0        16.0        Detroit Lions               TB
# 2502        BUF         7.0         9.0       Miami Dolphins              MIA
# 2503        CHI         6.0         3.0    Green Bay Packers              CHI
# 2504        DEN        10.0         0.0   Cincinnati Bengals              DEN
# 2505         KC        14.0         0.0      Baltimore Colts               KC
# ...         ...         ...         ...                  ...              ...
# 13226       TEN        16.0        19.0   Cincinnati Bengals              TEN
# 13227        KC        42.0        36.0        Buffalo Bills               KC
# 13228        TB        27.0        30.0     Los Angeles Rams               TB
# 13229        KC        24.0        27.0   Cincinnati Bengals               KC
# 13230       LAR        20.0        17.0  San Francisco 49ers              LAR
#
#        spread_favorite over_under_line                stadium  \
# 2501              -3.0              30     Houlihan's Stadium
# 2502              -5.0              39   Ralph Wilson Stadium
# 2503              -3.0              31          Soldier Field
# 2504              -3.0            31.5      Mile High Stadium
# 2505              -1.0              37      Arrowhead Stadium
# ...                ...             ...                    ...
# 13226             -4.0            48.5         Nissan Stadium
# 13227             -2.5            54.0      Arrowhead Stadium
# 13228             -3.0            48.0  Raymond James Stadium
# 13229             -7.0            54.5      Arrowhead Stadium
# 13230             -3.5            46.0           SoFi Stadium
#
#        stadium_neutral  weather_temperature  weather_wind_mph  \
# 2501             False                 79.0               9.0
# 2502             False                 74.0              15.0
# 2503             False                 78.0              11.0
# 2504             False                 69.0               6.0
# 2505             False                 76.0               8.0
# ...                ...                  ...               ...
# 13226            False                 35.0               0.0
# 13227            False                 35.0               6.0
# 13228            False                 50.0              11.0
# 13229            False                 41.0               4.0
# 13230            False                 72.0               0.0
#
#        weather_humidity weather_detail
# 2501               87.0            NaN
# 2502               74.0            NaN
# 2503               68.0            NaN
# 2504               38.0            NaN
# 2505               71.0            NaN
# ...                 ...            ...
# 13226              43.0            NaN
# 13227              54.0            NaN
# 13228              69.0            NaN
# 13229              41.0            NaN
# 13230               NaN           DOME
#
# [10484 rows x 17 columns]

# %%
away_teams = list(df['team_away'].values)
away_teams
# Out:
# ['Detroit Lions',
#  'Miami Dolphins',
#  'Green Bay Packers',
#  'Cincinnati Bengals',
#  'Baltimore Colts',
#  'Oakland Raiders',
#  'San Francisco 49ers',
#  'Atlanta Falcons',
#  'Cleveland Browns',
#  'New York Giants',
#  'San Diego Chargers',
#  'Dallas Cowboys',
#  'Houston Oilers',
#  'Pittsburgh Steelers',
#  'Los Angeles Rams',
#  'Cincinnati Bengals',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'New York Jets',
#  'St. Louis Cardinals',
#  'Houston Oilers',
#  'Oakland Raiders',
#  'Dallas Cowboys',
#  'Atlanta Falcons',
#  'Denver Broncos',
#  'New England Patriots',
#  'Baltimore Colts',
#  'Chicago Bears',
#  'Tampa Bay Buccaneers',
#  'Kansas City Chiefs',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'Philadelphia Eagles',
#  'Detroit Lions',
#  'Buffalo Bills',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'New York Giants',
#  'New York Jets',
#  'Houston Oilers',
#  'Seattle Seahawks',
#  'Atlanta Falcons',
#  'Oakland Raiders',
#  'Chicago Bears',
#  'Green Bay Packers',
#  'San Diego Chargers',
#  'Philadelphia Eagles',
#  'Baltimore Colts',
#  'Washington Redskins',
#  'Los Angeles Rams',
#  'Dallas Cowboys',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Tampa Bay Buccaneers',
#  'Cincinnati Bengals',
#  'Minnesota Vikings',
#  'Cleveland Browns',
#  'St. Louis Cardinals',
#  'New York Giants',
#  'Miami Dolphins',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Kansas City Chiefs',
#  'New England Patriots',
#  'Green Bay Packers',
#  'New York Jets',
#  'Chicago Bears',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Los Angeles Rams',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Seattle Seahawks',
#  'Miami Dolphins',
#  'Houston Oilers',
#  'New England Patriots',
#  'Pittsburgh Steelers',
#  'Washington Redskins',
#  'Los Angeles Rams',
#  'Detroit Lions',
#  'Denver Broncos',
#  'Buffalo Bills',
#  'San Francisco 49ers',
#  'Atlanta Falcons',
#  'Seattle Seahawks',
#  'Philadelphia Eagles',
#  'New Orleans Saints',
#  'Minnesota Vikings',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'St. Louis Cardinals',
#  'New York Giants',
#  'San Diego Chargers',
#  'Chicago Bears',
#  'Miami Dolphins',
#  'Detroit Lions',
#  'Oakland Raiders',
#  'Atlanta Falcons',
#  'Houston Oilers',
#  'Green Bay Packers',
#  'Philadelphia Eagles',
#  'Denver Broncos',
#  'San Diego Chargers',
#  'New England Patriots',
#  'Philadelphia Eagles',
#  'Kansas City Chiefs',
#  'Buffalo Bills',
#  'New York Jets',
#  'New York Giants',
#  'Green Bay Packers',
#  'Dallas Cowboys',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Cincinnati Bengals',
#  'New England Patriots',
#  'Detroit Lions',
#  'New Orleans Saints',
#  'New York Jets',
#  'San Diego Chargers',
#  'Dallas Cowboys',
#  'San Francisco 49ers',
#  'Cleveland Browns',
#  'Washington Redskins',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'Houston Oilers',
#  'San Diego Chargers',
#  'Seattle Seahawks',
#  'New England Patriots',
#  'Tampa Bay Buccaneers',
#  'Minnesota Vikings',
#  'Oakland Raiders',
#  'Pittsburgh Steelers',
#  'Baltimore Colts',
#  'San Francisco 49ers',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'St. Louis Cardinals',
#  'Philadelphia Eagles',
#  'Green Bay Packers',
#  'New York Jets',
#  'Cincinnati Bengals',
#  'Detroit Lions',
#  'Baltimore Colts',
#  'Kansas City Chiefs',
#  'St. Louis Cardinals',
#  'Pittsburgh Steelers',
#  'Denver Broncos',
#  'New Orleans Saints',
#  'New York Giants',
#  'Dallas Cowboys',
#  'Atlanta Falcons',
#  'Houston Oilers',
#  'Chicago Bears',
#  'New Orleans Saints',
#  'Miami Dolphins',
#  'St. Louis Cardinals',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'Buffalo Bills',
#  'Washington Redskins',
#  'Cleveland Browns',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New York Jets',
#  'New England Patriots',
#  'Denver Broncos',
#  'Houston Oilers',
#  'New York Giants',
#  'Seattle Seahawks',
#  'Minnesota Vikings',
#  'Baltimore Colts',
#  'Detroit Lions',
#  'Cincinnati Bengals',
#  'Atlanta Falcons',
#  'San Francisco 49ers',
#  'Chicago Bears',
#  'Green Bay Packers',
#  'Oakland Raiders',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Chicago Bears',
#  'Buffalo Bills',
#  'San Diego Chargers',
#  'New England Patriots',
#  'Cleveland Browns',
#  'Tampa Bay Buccaneers',
#  'New York Giants',
#  'Cincinnati Bengals',
#  'Pittsburgh Steelers',
#  'Green Bay Packers',
#  'New York Jets',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Cleveland Browns',
#  'Washington Redskins',
#  'Philadelphia Eagles',
#  'New Orleans Saints',
#  'Minnesota Vikings',
#  'Baltimore Colts',
#  'Seattle Seahawks',
#  'Buffalo Bills',
#  'Kansas City Chiefs',
#  'Denver Broncos',
#  'Miami Dolphins',
#  'Tampa Bay Buccaneers',
#  'Chicago Bears',
#  'Oakland Raiders',
#  'Detroit Lions',
#  'Atlanta Falcons',
#  'Cleveland Browns',
#  'San Francisco 49ers',
#  'Baltimore Colts',
#  'Denver Broncos',
#  'Houston Oilers',
#  'San Diego Chargers',
#  'New York Giants',
#  'Dallas Cowboys',
#  'Los Angeles Rams',
#  'Pittsburgh Steelers',
#  'New Orleans Saints',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'Seattle Seahawks',
#  'Cincinnati Bengals',
#  'Philadelphia Eagles',
#  'Atlanta Falcons',
#  'Washington Redskins',
#  'Oakland Raiders',
#  'St. Louis Cardinals',
#  'Houston Oilers',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'Pittsburgh Steelers',
#  'Kansas City Chiefs',
#  'Tampa Bay Buccaneers',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'Baltimore Colts',
#  'Green Bay Packers',
#  'Buffalo Bills',
#  'San Francisco 49ers',
#  'Washington Redskins',
#  'New England Patriots',
#  'New York Giants',
#  'New York Jets',
#  'Oakland Raiders',
#  'Houston Oilers',
#  'Minnesota Vikings',
#  'Dallas Cowboys',
#  'San Diego Chargers',
#  'New Orleans Saints',
#  'Los Angeles Rams',
#  'Chicago Bears',
#  'Atlanta Falcons',
#  'Philadelphia Eagles',
#  'Cleveland Browns',
#  'Seattle Seahawks',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Denver Broncos',
#  'New York Giants',
#  'Cincinnati Bengals',
#  'Seattle Seahawks',
#  'San Francisco 49ers',
#  'Baltimore Colts',
#  'Pittsburgh Steelers',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Kansas City Chiefs',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Tampa Bay Buccaneers',
#  'New York Jets',
#  'Baltimore Colts',
#  'San Francisco 49ers',
#  'New Orleans Saints',
#  'Houston Oilers',
#  'Chicago Bears',
#  'Miami Dolphins',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Los Angeles Rams',
#  'Green Bay Packers',
#  'Washington Redskins',
#  'New England Patriots',
#  'Detroit Lions',
#  'Minnesota Vikings',
#  'Green Bay Packers',
#  'Kansas City Chiefs',
#  'Tampa Bay Buccaneers',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'Seattle Seahawks',
#  'Dallas Cowboys',
#  'New York Giants',
#  'Los Angeles Rams',
#  'St. Louis Cardinals',
#  'Oakland Raiders',
#  'Los Angeles Rams',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'Minnesota Vikings',
#  'Cincinnati Bengals',
#  'Detroit Lions',
#  'Denver Broncos',
#  'Seattle Seahawks',
#  'Chicago Bears',
#  'Tampa Bay Buccaneers',
#  'New Orleans Saints',
#  'Miami Dolphins',
#  'Atlanta Falcons',
#  'San Diego Chargers',
#  'Houston Oilers',
#  'San Francisco 49ers',
#  'Baltimore Colts',
#  'New Orleans Saints',
#  'New York Jets',
#  'Miami Dolphins',
#  'Green Bay Packers',
#  'Philadelphia Eagles',
#  'Dallas Cowboys',
#  'New York Giants',
#  'Minnesota Vikings',
#  'Chicago Bears',
#  'Cleveland Browns',
#  'Washington Redskins',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'Detroit Lions',
#  'Philadelphia Eagles',
#  'Dallas Cowboys',
#  'Buffalo Bills',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Kansas City Chiefs',
#  'Atlanta Falcons',
#  'Pittsburgh Steelers',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Houston Oilers',
#  'Buffalo Bills',
#  'St. Louis Cardinals',
#  'New York Jets',
#  'Baltimore Colts',
#  'San Francisco 49ers',
#  'Tampa Bay Buccaneers',
#  'Los Angeles Rams',
#  'Green Bay Packers',
#  'Cleveland Browns',
#  'Kansas City Chiefs',
#  'Philadelphia Eagles',
#  'Oakland Raiders',
#  'San Diego Chargers',
#  'Chicago Bears',
#  'Pittsburgh Steelers',
#  'Cincinnati Bengals',
#  'Washington Redskins',
#  'Seattle Seahawks',
#  'Green Bay Packers',
#  'Baltimore Colts',
#  'Houston Oilers',
#  'Oakland Raiders',
#  'New York Giants',
#  'Kansas City Chiefs',
#  'Detroit Lions',
#  'Los Angeles Rams',
#  'Seattle Seahawks',
#  'Chicago Bears',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Tampa Bay Buccaneers',
#  'Cleveland Browns',
#  'Cincinnati Bengals',
#  'New York Jets',
#  'Minnesota Vikings',
#  'St. Louis Cardinals',
#  'Miami Dolphins',
#  'Philadelphia Eagles',
#  'New England Patriots',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'Green Bay Packers',
#  'Baltimore Colts',
#  'New York Jets',
#  'Denver Broncos',
#  'Dallas Cowboys',
#  'Atlanta Falcons',
#  'New Orleans Saints',
#  'New York Giants',
#  'Detroit Lions',
#  'Minnesota Vikings',
#  'San Diego Chargers',
#  'New England Patriots',
#  'Seattle Seahawks',
#  'New York Giants',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'Cincinnati Bengals',
#  'Oakland Raiders',
#  'Tampa Bay Buccaneers',
#  'Houston Oilers',
#  'Cleveland Browns',
#  'Buffalo Bills',
#  'New Orleans Saints',
#  'St. Louis Cardinals',
#  'Kansas City Chiefs',
#  'Dallas Cowboys',
#  'New York Jets',
#  'Chicago Bears',
#  'Kansas City Chiefs',
#  'Cleveland Browns',
#  'Philadelphia Eagles',
#  'Green Bay Packers',
#  'Minnesota Vikings',
#  'Atlanta Falcons',
#  'New England Patriots',
#  'Oakland Raiders',
#  'Buffalo Bills',
#  'Denver Broncos',
#  'Washington Redskins',
#  'Pittsburgh Steelers',
#  'Minnesota Vikings',
#  'New Orleans Saints',
#  'New York Jets',
#  'Green Bay Packers',
#  'Seattle Seahawks',
#  'Oakland Raiders',
#  'San Francisco 49ers',
#  'Houston Oilers',
#  'Baltimore Colts',
#  'Philadelphia Eagles',
#  'Kansas City Chiefs',
#  'Dallas Cowboys',
#  'San Diego Chargers',
#  'Pittsburgh Steelers',
#  'Buffalo Bills',
#  'Houston Oilers',
#  'St. Louis Cardinals',
#  'Atlanta Falcons',
#  'Tampa Bay Buccaneers',
#  'Los Angeles Rams',
#  'Cincinnati Bengals',
#  'New England Patriots',
#  'Detroit Lions',
#  'New York Giants',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Tampa Bay Buccaneers',
#  'Cleveland Browns',
#  'Baltimore Colts',
#  'Miami Dolphins',
#  'San Diego Chargers',
#  'Green Bay Packers',
#  'Detroit Lions',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'New York Jets',
#  'Washington Redskins',
#  'Dallas Cowboys',
#  'Miami Dolphins',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'New York Giants',
#  'San Diego Chargers',
#  'Oakland Raiders',
#  'Minnesota Vikings',
#  'Houston Oilers',
#  'Washington Redskins',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Kansas City Chiefs',
#  'St. Louis Cardinals',
#  'Los Angeles Rams',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'New York Jets',
#  'Chicago Bears',
#  'Kansas City Chiefs',
#  'Pittsburgh Steelers',
#  'Green Bay Packers',
#  'Denver Broncos',
#  'Seattle Seahawks',
#  'Dallas Cowboys',
#  'Detroit Lions',
#  'San Francisco 49ers',
#  'Atlanta Falcons',
#  'Los Angeles Rams',
#  'Cincinnati Bengals',
#  'Washington Redskins',
#  'Detroit Lions',
#  'Tampa Bay Buccaneers',
#  'Seattle Seahawks',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Cleveland Browns',
#  'Minnesota Vikings',
#  'Dallas Cowboys',
#  'Miami Dolphins',
#  'St. Louis Cardinals',
#  'San Diego Chargers',
#  'Pittsburgh Steelers',
#  'New Orleans Saints',
#  'Los Angeles Rams',
#  'San Francisco 49ers',
#  'Washington Redskins',
#  'Philadelphia Eagles',
#  'Houston Oilers',
#  'Buffalo Bills',
#  'Tampa Bay Buccaneers',
#  'New York Giants',
#  'Chicago Bears',
#  'New York Giants',
#  'Denver Broncos',
#  'San Diego Chargers',
#  'Baltimore Colts',
#  'Miami Dolphins',
#  'Green Bay Packers',
#  'Cincinnati Bengals',
#  'Seattle Seahawks',
#  'Kansas City Chiefs',
#  'Tampa Bay Buccaneers',
#  'Los Angeles Rams',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'Houston Oilers',
#  'Cleveland Browns',
#  'Houston Oilers',
#  'Seattle Seahawks',
#  'Detroit Lions',
#  'Baltimore Colts',
#  'Atlanta Falcons',
#  'New York Jets',
#  'New England Patriots',
#  'Dallas Cowboys',
#  'San Francisco 49ers',
#  'Kansas City Chiefs',
#  'Chicago Bears',
#  'St. Louis Cardinals',
#  'Minnesota Vikings',
#  'New York Jets',
#  'Cleveland Browns',
#  'New York Giants',
#  'Chicago Bears',
#  'New Orleans Saints',
#  'Tampa Bay Buccaneers',
#  'Miami Dolphins',
#  'Cincinnati Bengals',
#  'Atlanta Falcons',
#  'Pittsburgh Steelers',
#  'Philadelphia Eagles',
#  'Detroit Lions',
#  'Buffalo Bills',
#  'Pittsburgh Steelers',
#  'Los Angeles Rams',
#  'Dallas Cowboys',
#  'Chicago Bears',
#  'Houston Oilers',
#  'Oakland Raiders',
#  'New Orleans Saints',
#  'New York Jets',
#  'Washington Redskins',
#  'Baltimore Colts',
#  'Cleveland Browns',
#  'Buffalo Bills',
#  'Denver Broncos',
#  'San Diego Chargers',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Detroit Lions',
#  'Denver Broncos',
#  'Pittsburgh Steelers',
#  'Washington Redskins',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'San Diego Chargers',
#  'New York Giants',
#  'Green Bay Packers',
#  'Minnesota Vikings',
#  'Chicago Bears',
#  'Kansas City Chiefs',
#  'Washington Redskins',
#  'Cincinnati Bengals',
#  'Atlanta Falcons',
#  'Green Bay Packers',
#  'St. Louis Cardinals',
#  'Tampa Bay Buccaneers',
#  'Baltimore Colts',
#  'Los Angeles Rams',
#  'Denver Broncos',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Minnesota Vikings',
#  'San Francisco 49ers',
#  'Kansas City Chiefs',
#  'Detroit Lions',
#  'New England Patriots',
#  'Los Angeles Rams',
#  'Buffalo Bills',
#  'New York Jets',
#  'New Orleans Saints',
#  'Atlanta Falcons',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'New York Jets',
#  'Minnesota Vikings',
#  'Philadelphia Eagles',
#  'Seattle Seahawks',
#  'Miami Dolphins',
#  'Buffalo Bills',
#  'Green Bay Packers',
#  'Chicago Bears',
#  'Houston Oilers',
#  'New York Giants',
#  'San Diego Chargers',
#  'Baltimore Colts',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'Cincinnati Bengals',
#  'New England Patriots',
#  'Denver Broncos',
#  'Tampa Bay Buccaneers',
#  'Washington Redskins',
#  'Kansas City Chiefs',
#  'San Francisco 49ers',
#  'Green Bay Packers',
#  'St. Louis Cardinals',
#  'Cleveland Browns',
#  'Oakland Raiders',
#  'New England Patriots',
#  'Kansas City Chiefs',
#  'Houston Oilers',
#  'San Diego Chargers',
#  'Chicago Bears',
#  'Los Angeles Rams',
#  'Tampa Bay Buccaneers',
#  'St. Louis Cardinals',
#  'Atlanta Falcons',
#  'Miami Dolphins',
#  'Washington Redskins',
#  'Los Angeles Raiders',
#  'Cleveland Browns',
#  'Pittsburgh Steelers',
#  'Minnesota Vikings',
#  'Los Angeles Raiders',
#  'New Orleans Saints',
#  'Philadelphia Eagles',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'San Diego Chargers',
#  'Detroit Lions',
#  'Baltimore Colts',
#  'New York Jets',
#  'Cincinnati Bengals',
#  'Dallas Cowboys',
#  'Washington Redskins',
#  'Green Bay Packers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Detroit Lions',
#  'New England Patriots',
#  'Tampa Bay Buccaneers',
#  'Seattle Seahawks',
#  'Minnesota Vikings',
#  'Pittsburgh Steelers',
#  'Kansas City Chiefs',
#  'Baltimore Colts',
#  'Cincinnati Bengals',
#  'San Francisco 49ers',
#  'San Diego Chargers',
#  'Cleveland Browns',
#  'New York Giants',
#  'St. Louis Cardinals',
#  'Baltimore Colts',
#  'Los Angeles Raiders',
#  'Kansas City Chiefs',
#  'Chicago Bears',
#  'Houston Oilers',
#  'Green Bay Packers',
#  'Denver Broncos',
#  'New Orleans Saints',
#  'Pittsburgh Steelers',
#  'Philadelphia Eagles',
#  'Miami Dolphins',
#  'San Francisco 49ers',
#  'Cincinnati Bengals',
#  'New England Patriots',
#  'San Diego Chargers',
#  'Atlanta Falcons',
#  'Buffalo Bills',
#  'Seattle Seahawks',
#  'Minnesota Vikings',
#  'Tampa Bay Buccaneers',
#  'Houston Oilers',
#  'St. Louis Cardinals',
#  'Kansas City Chiefs',
#  'Dallas Cowboys',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'San Diego Chargers',
#  'New Orleans Saints',
#  'Cleveland Browns',
#  'Detroit Lions',
#  'Los Angeles Raiders',
#  'Denver Broncos',
#  'Baltimore Colts',
#  'Miami Dolphins',
#  'Tampa Bay Buccaneers',
#  'Chicago Bears',
#  'Washington Redskins',
#  'Dallas Cowboys',
#  'Los Angeles Rams',
#  'Green Bay Packers',
#  'St. Louis Cardinals',
#  'Pittsburgh Steelers',
#  'New Orleans Saints',
#  'Kansas City Chiefs',
#  'Minnesota Vikings',
#  'Houston Oilers',
#  'Atlanta Falcons',
#  'New England Patriots',
#  'Buffalo Bills',
#  'New York Giants',
#  'Cincinnati Bengals',
#  'Green Bay Packers',
#  'Seattle Seahawks',
#  'Philadelphia Eagles',
#  'Cleveland Browns',
#  'San Francisco 49ers',
#  'Denver Broncos',
#  'Chicago Bears',
#  'New York Jets',
#  'Washington Redskins',
#  'New England Patriots',
#  'Baltimore Colts',
#  'New York Giants',
#  'Detroit Lions',
#  'Buffalo Bills',
#  'Miami Dolphins',
#  'Cincinnati Bengals',
#  'New York Jets',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'New York Giants',
#  'Cleveland Browns',
#  'Los Angeles Raiders',
#  'Los Angeles Rams',
#  'Denver Broncos',
#  'Chicago Bears',
#  'St. Louis Cardinals',
#  'Dallas Cowboys',
#  'Philadelphia Eagles',
#  'Miami Dolphins',
#  'Atlanta Falcons',
#  'Los Angeles Raiders',
#  'Minnesota Vikings',
#  'Green Bay Packers',
#  'Seattle Seahawks',
#  'Baltimore Colts',
#  'St. Louis Cardinals',
#  'Los Angeles Rams',
#  'Denver Broncos',
#  'New York Jets',
#  'Detroit Lions',
#  'Dallas Cowboys',
#  'San Francisco 49ers',
#  'New York Giants',
#  'Denver Broncos',
#  'Tampa Bay Buccaneers',
#  'Buffalo Bills',
#  'Cleveland Browns',
#  'Pittsburgh Steelers',
#  'Houston Oilers',
#  'New Orleans Saints',
#  'New England Patriots',
#  'Seattle Seahawks',
#  'Dallas Cowboys',
#  'San Diego Chargers',
#  'Cincinnati Bengals',
#  'Baltimore Colts',
#  'New York Giants',
#  'Philadelphia Eagles',
#  'Atlanta Falcons',
#  'Los Angeles Rams',
#  'Pittsburgh Steelers',
#  'New York Jets',
#  'Chicago Bears',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Minnesota Vikings',
#  'Kansas City Chiefs',
#  'Miami Dolphins',
#  'Chicago Bears',
#  'Houston Oilers',
#  'New Orleans Saints',
#  'Los Angeles Raiders',
#  'Kansas City Chiefs',
#  'Detroit Lions',
#  'Los Angeles Rams',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Cleveland Browns',
#  'Atlanta Falcons',
#  'Washington Redskins',
#  'Cincinnati Bengals',
#  'Green Bay Packers',
#  'Philadelphia Eagles',
#  'Denver Broncos',
#  'Baltimore Colts',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'St. Louis Cardinals',
#  'Detroit Lions',
#  'Dallas Cowboys',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'San Diego Chargers',
#  'Houston Oilers',
#  'Los Angeles Raiders',
#  'New York Jets',
#  'New Orleans Saints',
#  'Minnesota Vikings',
#  'New York Jets',
#  'Tampa Bay Buccaneers',
#  'Green Bay Packers',
#  'Denver Broncos',
#  'Kansas City Chiefs',
#  'Buffalo Bills',
#  'Philadelphia Eagles',
#  'Seattle Seahawks',
#  'Los Angeles Rams',
#  'Washington Redskins',
#  'Pittsburgh Steelers',
#  'Buffalo Bills',
#  'Philadelphia Eagles',
#  'Cincinnati Bengals',
#  'Chicago Bears',
#  'New York Giants',
#  'Atlanta Falcons',
#  'Houston Oilers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Miami Dolphins',
#  'Cleveland Browns',
#  'Los Angeles Raiders',
#  'St. Louis Cardinals',
#  'Washington Redskins',
#  'Miami Dolphins',
#  'New England Patriots',
#  'Los Angeles Raiders',
#  'San Diego Chargers',
#  'Minnesota Vikings',
#  'Kansas City Chiefs',
#  'Atlanta Falcons',
#  'Chicago Bears',
#  'New Orleans Saints',
#  'Detroit Lions',
#  'New York Giants',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Seattle Seahawks',
#  'Los Angeles Rams',
#  'Dallas Cowboys',
#  'Baltimore Colts',
#  'Tampa Bay Buccaneers',
#  'New York Jets',
#  'Minnesota Vikings',
#  'Washington Redskins',
#  'Cleveland Browns',
#  'Cincinnati Bengals',
#  'Los Angeles Raiders',
#  'Chicago Bears',
#  'Tampa Bay Buccaneers',
#  'Buffalo Bills',
#  'Atlanta Falcons',
#  'Baltimore Colts',
#  'Dallas Cowboys',
#  'San Diego Chargers',
#  'Miami Dolphins',
#  'Denver Broncos',
#  'St. Louis Cardinals',
#  'New York Giants',
#  'Pittsburgh Steelers',
#  'Tampa Bay Buccaneers',
#  'Detroit Lions',
#  'Cincinnati Bengals',
#  'Denver Broncos',
#  'Green Bay Packers',
#  'Miami Dolphins',
#  'Washington Redskins',
#  'Buffalo Bills',
#  'Dallas Cowboys',
#  'New Orleans Saints',
#  'Seattle Seahawks',
#  'Los Angeles Rams',
#  'San Francisco 49ers',
#  'Los Angeles Raiders',
#  'Houston Oilers',
#  'Kansas City Chiefs',
#  'Seattle Seahawks',
#  'Detroit Lions',
#  'Washington Redskins',
#  'Baltimore Colts',
#  'Cleveland Browns',
#  'New York Giants',
#  'Minnesota Vikings',
#  'San Diego Chargers',
#  'New York Jets',
#  'St. Louis Cardinals',
#  'Pittsburgh Steelers',
#  'Green Bay Packers',
#  'San Francisco 49ers',
#  'Baltimore Colts',
#  'New York Giants',
#  'Buffalo Bills',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'Denver Broncos',
#  'Kansas City Chiefs',
#  'Houston Oilers',
#  'Philadelphia Eagles',
#  'Cincinnati Bengals',
#  'Los Angeles Raiders',
#  'New York Jets',
#  'Cleveland Browns',
#  'Chicago Bears',
#  'Miami Dolphins',
#  'Buffalo Bills',
#  'St. Louis Cardinals',
#  'Los Angeles Rams',
#  'Cincinnati Bengals',
#  'Tampa Bay Buccaneers',
#  'Dallas Cowboys',
#  'Atlanta Falcons',
#  'Minnesota Vikings',
#  'Atlanta Falcons',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Detroit Lions',
#  'Washington Redskins',
#  'Baltimore Colts',
#  'Cleveland Browns',
#  'St. Louis Cardinals',
#  'New England Patriots',
#  'Chicago Bears',
#  'Seattle Seahawks',
#  'New Orleans Saints',
#  'Kansas City Chiefs',
#  'Green Bay Packers',
#  'New York Jets',
#  'Cincinnati Bengals',
#  'New York Giants',
#  'Buffalo Bills',
#  'Houston Oilers',
#  'Green Bay Packers',
#  'Pittsburgh Steelers',
#  'Tampa Bay Buccaneers',
#  'Denver Broncos',
#  'San Diego Chargers',
#  'Los Angeles Rams',
#  'New England Patriots',
#  'Philadelphia Eagles',
#  'New England Patriots',
#  'Tampa Bay Buccaneers',
#  'Cincinnati Bengals',
#  'San Francisco 49ers',
#  'St. Louis Cardinals',
#  'Los Angeles Raiders',
#  'New York Jets',
#  'San Diego Chargers',
#  'Atlanta Falcons',
#  'Philadelphia Eagles',
#  ...]

# %%
away_team_ab = []
for team in away_teams:
    if team.__contains__('Cardinals'):
        away_team_ab.append('ARI')
    elif team.__contains__('Falcons'):
        away_team_ab.append('ATL')
    elif team.__contains__('Ravens'):
        away_team_ab.append('BAL')
    elif team.__contains__('Bills'):
        away_team_ab.append('BUF')
    elif team.__contains__('Panthers'):
        away_team_ab.append('CAR')
    elif team.__contains__('Bears'):
        away_team_ab.append('CHI')
    elif team.__contains__('Bengals'):
        away_team_ab.append('CIN')
    elif team.__contains__('Browns'):
        away_team_ab.append('CLE')
    elif team.__contains__('Cowboys'):
        away_team_ab.append('DAL')
    elif team.__contains__('Broncos'):
        away_team_ab.append('DEN')
    elif team.__contains__('Lions'):
        away_team_ab.append('DET')
    elif team.__contains__('Packers'):
        away_team_ab.append('GB')
    elif team.__contains__('Texans'):
        away_team_ab.append('HOU')
    elif team.__contains__('Colts'):
        away_team_ab.append('IND')
    elif team.__contains__('Jaguars'):
        away_team_ab.append('JAX')
    elif team.__contains__('Chiefs'):
        away_team_ab.append('KC')
    elif team.__contains__('Chargers'):
        away_team_ab.append('LAC')
    elif team.__contains__('Rams'):
        away_team_ab.append('LAR')
    elif team.__contains__('Dolphins'):
        away_team_ab.append('MIA')
    elif team.__contains__('Vikings'):
        away_team_ab.append('MIN')
    elif team.__contains__('Patriots'):
        away_team_ab.append('NE')
    elif team.__contains__('Saints'):
        away_team_ab.append('NO')
    elif team.__contains__('Giants'):
        away_team_ab.append('NYG')
    elif team.__contains__('Jets'):
        away_team_ab.append('NYJ')
    elif team.__contains__('Raiders'):
        away_team_ab.append('LVR')
    elif team.__contains__('Eagles'):
        away_team_ab.append('PHI')
    elif team.__contains__('Steelers'):
        away_team_ab.append('PIT')
    elif team.__contains__('Seahawks'):
        away_team_ab.append('SEA')
    elif team.__contains__('49ers'):
        away_team_ab.append('SF')
    elif team.__contains__('Buccaneers'):
        away_team_ab.append('TB')
    elif team.__contains__('Oilers'):
        away_team_ab.append('TEN')
    elif team.__contains__('Titans'):
        away_team_ab.append('TEN')
    elif team.__contains__('Redskins'):
        away_team_ab.append('WAS')
    elif team.__contains__('Football Team'):
        away_team_ab.append('WAS')

# %%
df['team_away'] = away_team_ab

# %%
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2501         TB        31.0        16.0       DET               TB
# 2502        BUF         7.0         9.0       MIA              MIA
# 2503        CHI         6.0         3.0        GB              CHI
# 2504        DEN        10.0         0.0       CIN              DEN
# 2505         KC        14.0         0.0       IND               KC
# ...         ...         ...         ...       ...              ...
# 13226       TEN        16.0        19.0       CIN              TEN
# 13227        KC        42.0        36.0       BUF               KC
# 13228        TB        27.0        30.0       LAR               TB
# 13229        KC        24.0        27.0       CIN               KC
# 13230       LAR        20.0        17.0        SF              LAR
#
#        spread_favorite over_under_line                stadium  \
# 2501              -3.0              30     Houlihan's Stadium
# 2502              -5.0              39   Ralph Wilson Stadium
# 2503              -3.0              31          Soldier Field
# 2504              -3.0            31.5      Mile High Stadium
# 2505              -1.0              37      Arrowhead Stadium
# ...                ...             ...                    ...
# 13226             -4.0            48.5         Nissan Stadium
# 13227             -2.5            54.0      Arrowhead Stadium
# 13228             -3.0            48.0  Raymond James Stadium
# 13229             -7.0            54.5      Arrowhead Stadium
# 13230             -3.5            46.0           SoFi Stadium
#
#        stadium_neutral  weather_temperature  weather_wind_mph  \
# 2501             False                 79.0               9.0
# 2502             False                 74.0              15.0
# 2503             False                 78.0              11.0
# 2504             False                 69.0               6.0
# 2505             False                 76.0               8.0
# ...                ...                  ...               ...
# 13226            False                 35.0               0.0
# 13227            False                 35.0               6.0
# 13228            False                 50.0              11.0
# 13229            False                 41.0               4.0
# 13230            False                 72.0               0.0
#
#        weather_humidity weather_detail
# 2501               87.0            NaN
# 2502               74.0            NaN
# 2503               68.0            NaN
# 2504               38.0            NaN
# 2505               71.0            NaN
# ...                 ...            ...
# 13226              43.0            NaN
# 13227              54.0            NaN
# 13228              69.0            NaN
# 13229              41.0            NaN
# 13230               NaN           DOME
#
# [10484 rows x 17 columns]

# %%
n_home_teams = list(df['team_home'].values)

# %%
n_away_teams = list(df['team_away'].values)

# %%
fav_team = list(df['team_favorite_id'])

# %%
score_home = list(df['score_home'].values)

# %%
score_away = list(df['score_away'].values)

# %%
favorite_win = []
for score in list(range(len(df))):
    if score_home[score] > score_away[score]:
        if n_home_teams[score] == fav_team[score]:
            favorite_win.append(True)
        else:
            favorite_win.append(False)
    elif score_home[score] < score_away[score]:
        if n_away_teams[score] == fav_team[score]:
            favorite_win.append(True)
        else:
            favorite_win.append(False)
    elif score_home[score] == score_away[score]:
        favorite_win.append(False)

# %%
favorite_win
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  ...]

# %%
df['favorite_wins'] = favorite_win

# %%
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2501         TB        31.0        16.0       DET               TB
# 2502        BUF         7.0         9.0       MIA              MIA
# 2503        CHI         6.0         3.0        GB              CHI
# 2504        DEN        10.0         0.0       CIN              DEN
# 2505         KC        14.0         0.0       IND               KC
# ...         ...         ...         ...       ...              ...
# 13226       TEN        16.0        19.0       CIN              TEN
# 13227        KC        42.0        36.0       BUF               KC
# 13228        TB        27.0        30.0       LAR               TB
# 13229        KC        24.0        27.0       CIN               KC
# 13230       LAR        20.0        17.0        SF              LAR
#
#        spread_favorite over_under_line                stadium  \
# 2501              -3.0              30     Houlihan's Stadium
# 2502              -5.0              39   Ralph Wilson Stadium
# 2503              -3.0              31          Soldier Field
# 2504              -3.0            31.5      Mile High Stadium
# 2505              -1.0              37      Arrowhead Stadium
# ...                ...             ...                    ...
# 13226             -4.0            48.5         Nissan Stadium
# 13227             -2.5            54.0      Arrowhead Stadium
# 13228             -3.0            48.0  Raymond James Stadium
# 13229             -7.0            54.5      Arrowhead Stadium
# 13230             -3.5            46.0           SoFi Stadium
#
#        stadium_neutral  weather_temperature  weather_wind_mph  \
# 2501             False                 79.0               9.0
# 2502             False                 74.0              15.0
# 2503             False                 78.0              11.0
# 2504             False                 69.0               6.0
# 2505             False                 76.0               8.0
# ...                ...                  ...               ...
# 13226            False                 35.0               0.0
# 13227            False                 35.0               6.0
# 13228            False                 50.0              11.0
# 13229            False                 41.0               4.0
# 13230            False                 72.0               0.0
#
#        weather_humidity weather_detail  favorite_wins
# 2501               87.0            NaN           True
# 2502               74.0            NaN           True
# 2503               68.0            NaN           True
# 2504               38.0            NaN           True
# 2505               71.0            NaN           True
# ...                 ...            ...            ...
# 13226              43.0            NaN          False
# 13227              54.0            NaN           True
# 13228              69.0            NaN          False
# 13229              41.0            NaN          False
# 13230               NaN           DOME           True
#
# [10484 rows x 18 columns]

# %%
len(df['stadium'].value_counts())
# Out:
# 86

# %%
df = df.drop(columns='weather_humidity')

# %%
df = df.drop(columns='weather_detail')

# %%
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 13226     1/22/2022             2021      Division              True
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
#
#       team_home  score_home  score_away team_away team_favorite_id  \
# 2501         TB        31.0        16.0       DET               TB
# 2502        BUF         7.0         9.0       MIA              MIA
# 2503        CHI         6.0         3.0        GB              CHI
# 2504        DEN        10.0         0.0       CIN              DEN
# 2505         KC        14.0         0.0       IND               KC
# ...         ...         ...         ...       ...              ...
# 13226       TEN        16.0        19.0       CIN              TEN
# 13227        KC        42.0        36.0       BUF               KC
# 13228        TB        27.0        30.0       LAR               TB
# 13229        KC        24.0        27.0       CIN               KC
# 13230       LAR        20.0        17.0        SF              LAR
#
#        spread_favorite over_under_line                stadium  \
# 2501              -3.0              30     Houlihan's Stadium
# 2502              -5.0              39   Ralph Wilson Stadium
# 2503              -3.0              31          Soldier Field
# 2504              -3.0            31.5      Mile High Stadium
# 2505              -1.0              37      Arrowhead Stadium
# ...                ...             ...                    ...
# 13226             -4.0            48.5         Nissan Stadium
# 13227             -2.5            54.0      Arrowhead Stadium
# 13228             -3.0            48.0  Raymond James Stadium
# 13229             -7.0            54.5      Arrowhead Stadium
# 13230             -3.5            46.0           SoFi Stadium
#
#        stadium_neutral  weather_temperature  weather_wind_mph  favorite_wins
# 2501             False                 79.0               9.0           True
# 2502             False                 74.0              15.0           True
# 2503             False                 78.0              11.0           True
# 2504             False                 69.0               6.0           True
# 2505             False                 76.0               8.0           True
# ...                ...                  ...               ...            ...
# 13226            False                 35.0               0.0          False
# 13227            False                 35.0               6.0           True
# 13228            False                 50.0              11.0          False
# 13229            False                 41.0               4.0          False
# 13230            False                 72.0               0.0           True
#
# [10484 rows x 16 columns]

# %%
df['team_home'].value_counts()
# Out:
# NE     360
# PIT    358
# SF     357
# DEN    356
# PHI    355
# GB     353
# KC     350
# NYG    348
# MIN    348
# DAL    348
# BUF    347
# CHI    347
# TEN    346
# NO     345
# IND    345
# MIA    345
# SEA    344
# LVR    343
# WAS    342
# LAR    342
# ATL    340
# LAC    340
# TB     339
# ARI    339
# CIN    339
# NYJ    338
# DET    334
# CLE    315
# JAX    220
# CAR    219
# BAL    215
# HOU    167
# Name: team_home, dtype: int64

# %%
df['weather_temperature'].value_counts()
# Out:
#  72.0    2498
#  60.0     215
#  56.0     201
#  62.0     191
#  64.0     189
#          ...
#  3.0        1
# -3.0        1
#  4.0        1
# -6.0        1
#  93.0       1
# Name: weather_temperature, Length: 98, dtype: int64

# %%
df[["month", "day", "year"]] = df["schedule_date"].str.split("/", expand = True)

# %%
df = df.drop(columns='day')

# %%
df = df.drop(columns='year')

# %%
df = df.drop(columns='schedule_date')

# %%
df = df.drop(columns='schedule_week')

# %%
df
# Out:
#        schedule_season  schedule_playoff team_home  score_home  score_away  \
# 2501              1979             False        TB        31.0        16.0
# 2502              1979             False       BUF         7.0         9.0
# 2503              1979             False       CHI         6.0         3.0
# 2504              1979             False       DEN        10.0         0.0
# 2505              1979             False        KC        14.0         0.0
# ...                ...               ...       ...         ...         ...
# 13226             2021              True       TEN        16.0        19.0
# 13227             2021              True        KC        42.0        36.0
# 13228             2021              True        TB        27.0        30.0
# 13229             2021              True        KC        24.0        27.0
# 13230             2021              True       LAR        20.0        17.0
#
#       team_away team_favorite_id  spread_favorite over_under_line  \
# 2501        DET               TB             -3.0              30
# 2502        MIA              MIA             -5.0              39
# 2503         GB              CHI             -3.0              31
# 2504        CIN              DEN             -3.0            31.5
# 2505        IND               KC             -1.0              37
# ...         ...              ...              ...             ...
# 13226       CIN              TEN             -4.0            48.5
# 13227       BUF               KC             -2.5            54.0
# 13228       LAR               TB             -3.0            48.0
# 13229       CIN               KC             -7.0            54.5
# 13230        SF              LAR             -3.5            46.0
#
#                      stadium  stadium_neutral  weather_temperature  \
# 2501      Houlihan's Stadium            False                 79.0
# 2502    Ralph Wilson Stadium            False                 74.0
# 2503           Soldier Field            False                 78.0
# 2504       Mile High Stadium            False                 69.0
# 2505       Arrowhead Stadium            False                 76.0
# ...                      ...              ...                  ...
# 13226         Nissan Stadium            False                 35.0
# 13227      Arrowhead Stadium            False                 35.0
# 13228  Raymond James Stadium            False                 50.0
# 13229      Arrowhead Stadium            False                 41.0
# 13230           SoFi Stadium            False                 72.0
#
#        weather_wind_mph  favorite_wins month
# 2501                9.0           True     9
# 2502               15.0           True     9
# 2503               11.0           True     9
# 2504                6.0           True     9
# 2505                8.0           True     9
# ...                 ...            ...   ...
# 13226               0.0          False     1
# 13227               6.0           True     1
# 13228              11.0          False     1
# 13229               4.0          False     1
# 13230               0.0           True     1
#
# [10484 rows x 15 columns]

# %%
df['month'] = df['month'].astype(int)

# %%
df['month'].dtype
# Out:
# dtype('int64')

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score, plot_roc_curve
from sklearn.compose import ColumnTransformer

X = df.drop(columns="favorite_wins")
y = df['favorite_wins']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.base import BaseEstimator
class GroupImputer(BaseEstimator):
    
    def __init__(self, fill_col, group_col, strategy):
        self.fill_col = fill_col
        self.group_col = group_col
        self.strategy = strategy
    
    def fit(self, X, y=None):
        self.val_by_group = X.groupby(self.group_col)[self.fill_col].agg([self.strategy]).to_dict()[self.strategy]
        
    def transform(self, X):
        X.loc[:, self.fill_col] = X[self.fill_col].fillna(X[self.group_col].map(self.val_by_group))
        return X

# %%
group_imputer = GroupImputer(fill_col= 'weather_temperature', group_col='team_home', strategy='mean')

# %%
group_imputer.fit(X_train)

# %%
sns.pairplot(X_train);
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
X_train = group_imputer.transform(X_train)
X_test = group_imputer.transform(X_test)
# Out:
# /Users/reesethompson/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
class windImputer(BaseEstimator):
    
    def __init__(self, fill_col, wind_col, strategy):
        self.fill_col = fill_col
        self.wind_col = wind_col
        self.strategy = strategy
    
    def fit(self, X, y=None):
        self.val_by_wind = X.groupby(self.wind_col)[self.fill_col].agg([self.strategy]).to_dict()[self.strategy]
        
    def transform(self, X):
        X.loc[:, self.fill_col] = X[self.fill_col].fillna(X[self.wind_col].map(self.val_by_wind))
        return X

# %%
wind_imputer = GroupImputer(fill_col= 'weather_wind_mph', group_col='team_home', strategy='mean')

# %%
wind_imputer.fit(X_train)

# %%
X_train = wind_imputer.transform(X_train)
X_test = wind_imputer.transform(X_test)

# %%
X_train['weather_wind_mph'].isna().sum()
# Out:
# 0

# %%
cat_columns = [c for c in X_train.columns if X_train[c].dtype == 'O']
cat_columns
# Out:
# ['team_home', 'team_away', 'team_favorite_id', 'over_under_line', 'stadium']

# %%
[c for c in X_train.columns if X_train[c].dtype in ['int64', 'float64']]
# Out:
# ['schedule_season',
#  'score_home',
#  'score_away',
#  'spread_favorite',
#  'weather_temperature',
#  'weather_wind_mph',
#  'month']

# %%
num_columns = [ 
'schedule_season',
 'score_home',
 'score_away',
 'spread_favorite',
 'weather_temperature',
 'weather_wind_mph',
 'month',   
 'schedule_playoff',
 'stadium_neutral',   ]

# %%
cat_transformer = OneHotEncoder(drop='first')
num_transformer = StandardScaler()

preprocessor = ColumnTransformer([
    ('cats', cat_transformer, cat_columns),
    ('nums', num_transformer, num_columns)
])

# %%
used_cols = [*cat_columns, *num_columns]
used_cols
# Out:
# ['team_home',
#  'team_away',
#  'team_favorite_id',
#  'over_under_line',
#  'stadium',
#  'schedule_season',
#  'score_home',
#  'score_away',
#  'spread_favorite',
#  'weather_temperature',
#  'weather_wind_mph',
#  'month',
#  'schedule_playoff',
#  'stadium_neutral']

# %%
df
# Out:
#        schedule_season  schedule_playoff team_home  score_home  score_away  \
# 2501              1979             False        TB        31.0        16.0
# 2502              1979             False       BUF         7.0         9.0
# 2503              1979             False       CHI         6.0         3.0
# 2504              1979             False       DEN        10.0         0.0
# 2505              1979             False        KC        14.0         0.0
# ...                ...               ...       ...         ...         ...
# 13226             2021              True       TEN        16.0        19.0
# 13227             2021              True        KC        42.0        36.0
# 13228             2021              True        TB        27.0        30.0
# 13229             2021              True        KC        24.0        27.0
# 13230             2021              True       LAR        20.0        17.0
#
#       team_away team_favorite_id  spread_favorite over_under_line  \
# 2501        DET               TB             -3.0              30
# 2502        MIA              MIA             -5.0              39
# 2503         GB              CHI             -3.0              31
# 2504        CIN              DEN             -3.0            31.5
# 2505        IND               KC             -1.0              37
# ...         ...              ...              ...             ...
# 13226       CIN              TEN             -4.0            48.5
# 13227       BUF               KC             -2.5            54.0
# 13228       LAR               TB             -3.0            48.0
# 13229       CIN               KC             -7.0            54.5
# 13230        SF              LAR             -3.5            46.0
#
#                      stadium  stadium_neutral  weather_temperature  \
# 2501      Houlihan's Stadium            False                 79.0
# 2502    Ralph Wilson Stadium            False                 74.0
# 2503           Soldier Field            False                 78.0
# 2504       Mile High Stadium            False                 69.0
# 2505       Arrowhead Stadium            False                 76.0
# ...                      ...              ...                  ...
# 13226         Nissan Stadium            False                 35.0
# 13227      Arrowhead Stadium            False                 35.0
# 13228  Raymond James Stadium            False                 50.0
# 13229      Arrowhead Stadium            False                 41.0
# 13230           SoFi Stadium            False                 72.0
#
#        weather_wind_mph  favorite_wins  month
# 2501                9.0           True      9
# 2502               15.0           True      9
# 2503               11.0           True      9
# 2504                6.0           True      9
# 2505                8.0           True      9
# ...                 ...            ...    ...
# 13226               0.0          False      1
# 13227               6.0           True      1
# 13228              11.0          False      1
# 13229               4.0          False      1
# 13230               0.0           True      1
#
# [10484 rows x 15 columns]
